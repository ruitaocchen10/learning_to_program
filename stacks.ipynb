# %%
""" Design a stack class that supports the push, pop, top, and getMin operations.

MinStack() initializes the stack object.
void push(int val) pushes the element val onto the stack.
void pop() removes the element on the top of the stack.
int top() gets the top element of the stack.
int getMin() retrieves the minimum element in the stack.
 """

class MinStack:
    def __init__(self):
        self.stack = []
        self.min_val = []

    def push(self, val: int) -> None:
        self.stack.append(val)
        if not self.min_val:
            self.min_val.append(val)
        elif val <= self.min_val[-1]:
            self.min_val.append(val)

    def pop(self) -> None:
        popped = self.stack.pop()

        if popped == self.min_val[-1]:
            self.min_val.pop()
        
    def top(self) -> int:
        return self.stack[-1]

    def getMin(self) -> int:
        return self.min_val[-1]

operations = ["MinStack", "push", "push", "push", "getMin", "pop", "top", "getMin"]
values = [None, 1, 2, 0, None, None, None, None]

solution = MinStack()

for op, val in zip(operations, values):
    if op == "push":
        solution.push(val)
    elif op == "pop":
        solution.pop()
    elif op == "top":
        print(solution.top())
    elif op == "getMin":
        print(solution.getMin())
# Out:
# 0
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 48
#      46     print(solution.top())
#      47 elif op == "getMin":
# ---> 48     print(solution.getMin())
#
# Cell In[7], line 33, in MinStack.getMin(self)
#      32 def getMin(self) -> int:
# ---> 33     return self.min_val[-1]
#
# IndexError: list index out of range
