# %%
# Given the beginning of a singly linked list head, reverse the list, and return the new beginning of the list.

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def reverseList(self, head):
        curr = head
        prev = None

        while curr:
            next_node = curr.next
            curr.next = prev
            prev = curr
            curr = next_node

        return prev


head = ListNode(0, ListNode(1, ListNode(2, ListNode(3))))
solution = Solution()
answer = solution.reverseList(head)
print(answer)
# Out:
# <__main__.ListNode object at 0x10c3d5be0>
