# %%
#two pointers pattern

#using two pointers to iterate through the data structure until one or both pointers hit a certain condition

#more efficient than brute force with one pointer which would have a space complexity of O(n^2)

# %%
#Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.

#You may assume that each input would have exactly one solution, and you may not use the same element twice.

#You can return the answer in any order.

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        hashmap = {} # Empty dictionary to store each number and index
        for i in range(len(nums)): #range stores nums as indices
            hashmap[nums[i]] = i #Stores key nums[i] (which is the number in the array), and value i (index)
        for i in range(len(nums)): #For each value in nums
            complement = target - nums[i] #Creates a compliment value for each num
            if complement in hashmap and hashmap[complement] != i: #if compliment is in the hashmap and compliment is not = existing number
                return [i, hashmap[complement]] #return the list of the two indices
        # If no valid pair is found, return an empty list
        return []

# %%
string = "A man, a plan, a canal: Panama"

def palindrome(string):
    #string_split = string.split() 
    string = string.lower() #convert to lowercase
    
    front = 0
    back = len(string) - 1

    while front < back:
        if not string[front].isalnum(): #skips non-alphanumeric char from front
            front += 1
            continue

        if not string[back].isalnum(): #skips non-alphanumeric char from back
            front += 1
            continue

        if string[front] != string[back]:
            return False

        front += 1
        back -= 1

    return True

palindrome(string)
# Out:
# True

# %%
def form(numbers, target):
    start = 0
    end = len(numbers) - 1

    while start < end: #while loop 
        current_sum = numbers[start] + numbers[end]

        if current_sum == target:
            return [start + 1, end + 1]
        elif current_sum > target:
            end -= 1
        else:
            start += 1  

    return []              
        
numbers = [2, 7, 11, 15]
target = 9

form(numbers, target)
# Out:
# [1, 2]

# %%
# reversing a string array 

def reverse(s):
    start = 0
    end = len(s) - 1

    while start < end:
        s[start], s[end] = s[end], s[start]
        # temp = s[start]
        # s[start] = s[end]
        # s[end] = temp
        start += 1
        end -= 1

    return s

s = ["h", "e", "l", "l", "o"]

print(reverse(s))
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %%
def swap(nums):
    slow = 0

    for fast in range(1, len(nums)):
        if nums[fast] != 0:
            nums[slow], nums[fast] = nums[fast], nums[slow]
            slow += 1

    return nums

nums = [0, 1, 0, 3, 12]
swap(nums)
# Out:
# [1, 3, 12, 0, 0]

# %%
def squares(nums):
    n = len(nums)
    result = [0] * n
    start = 0
    end = n - 1
    position = n - 1

    while start <= end:
        start_squared = nums[start] ** 2
        end_squared = nums[end] ** 2
        
        if start_squared > end_squared:
            result[position] = start_squared
            start += 1
        else:
            result[position] = end_squared
            end -= 1
        
        position -= 1

    return result

nums = [-4, -1, 0, 3, 10]
print(squares(nums))
# Out:
# [0, 1, 9, 16, 100]

# %%
def area(height):
    left = 0
    right = len(height) - 1
    area = 0

    while left < right:
        w = right - left
        h = min(height[left], height[right])
        a = w * h
        if a > area:
            area = a
            left += 1
        else:
            right -=1

    return area

height = [1, 8, 6, 2, 5, 4, 8, 3, 7]
area(height)
# Out:
# 49

# %%
def match(nums1, nums2):
    nums1.sort()
    nums2.sort()
    first = 0
    second = 0
    output = []

    while first < len(nums1) and second < len(nums2):
        if nums1[first] == nums2[second]:
            output.append(nums1[first])
            first += 1
            second += 1
        elif nums1[first] > nums2[second]:
            second += 1
        else:
            first += 1

    return output

nums1 = [4, 9, 5]
nums2 = [9, 4, 9, 8, 4]
match(nums1, nums2)
# Out:
# [4, 9]

# %%
def subsequence(s, t):
    s_ct = 0
    t_ct = 0

    while s_ct < len(s) and t_ct < len(t):
        if s[s_ct] == t[t_ct]:
            s_ct += 1
            t_ct += 1
        elif s[s_ct] != t[t_ct]:
            t_ct += 1
    
    return s_ct == len(s)
    
s = "axc"
t = "ahbgdc"
subsequence(s, t)
# Out:
# False

# %%
def occurence(needle, haystack):
    n = 0
    h = 0

    while n < len(needle) and h < len(haystack):
        if haystack[h] == needle[n]:
            n += 1
            h += 1
        else:
            n = 0
    
    result = h - n
    if n != len(needle):
        return -1
    else:
        return result

haystack = "leetcode"
needle = "leeto"
occurence(needle, haystack)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 20
#      18 haystack = "leetcode"
#      19 needle = "leeto"
# ---> 20 occurence(needle, haystack)
#
# Cell In[34], line 5, in occurence(needle, haystack)
#       2 n = 0
#       3 h = 0
# ----> 5 while n < len(needle) and h < len(haystack):
#       6     if haystack[h] == needle[n]:
#       7         n += 1
#
# KeyboardInterrupt:
