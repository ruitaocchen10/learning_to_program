# %%
# Class Practice

class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.amount = amount
        self.balance += self.amount

    def withdraw(self, amount):
        self.amount = amount
        self.balance -= self.amount

    def get_balance(self):
        return self.balance


account = BankAccount("Ruitao", 0)

account.deposit(100)
account.withdraw(40)

print(account.get_balance())
# Out:
# 60

# %%
# Linked Lists are made ourselves, vs. arrays which is an existing data structure in coding languages
# Elements are called nodes
# Elements can be inserted and deleted in constant time, with no shifting in operations needed


#create singly linked list
class LinkedList:
    
    def __init__(self, data, next = None):
        self.data = data
        self.next = next
    
    def get(self, index: int) -> int:
        

    def insertHead(self, val: int) -> None:
        

    def insertTail(self, val: int) -> None:
        

    def remove(self, index: int) -> bool:
        

    def getValues(self) -> List[int]:
