# %%
import pandas as pd

data = {
    'Names': ['Alice', 'Bob', 'Carol', 'David'],
    'Ages': [20, 22, 21, 23],
    'Grades': [85, 78, 92, 88]
}
df = pd.DataFrame(data) #keys = columns, list = values
print(df)
print(df.shape)
# Out:
#    Names  Ages  Grades
# 0  Alice    20      85
# 1    Bob    22      78
# 2  Carol    21      92
# 3  David    23      88
# (4, 3)
